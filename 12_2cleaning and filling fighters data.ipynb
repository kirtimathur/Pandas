# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\asus\\OneDrive\\Desktop\\Python@ms\\data_sets\\upcoming-event.csv")
data.head()
# Out:
#          R_fighter         B_fighter  R_odds  B_odds        R_ev        B_ev  \
# 0   Mackenzie Dern  Marina Rodriguez    -195     165   51.282051  165.000000
# 1      Randy Brown      Jared Gooden    -265     215   37.735849  215.000000
# 2      Tim Elliott   Matheus Nicolau     155    -180  155.000000   55.555556
# 3      Sabina Mazo    Mariya Agapova    -190     160   52.631579  160.000000
# 4  Chris Gutierrez    Felipe Colares    -235     190   42.553191  190.000000
#
#          date                location country  Winner  ...  finish_details  \
# 0  2021-10-09  Las Vegas, Nevada, USA     USA     NaN  ...             NaN
# 1  2021-10-09  Las Vegas, Nevada, USA     USA     NaN  ...             NaN
# 2  2021-10-09  Las Vegas, Nevada, USA     USA     NaN  ...             NaN
# 3  2021-10-09  Las Vegas, Nevada, USA     USA     NaN  ...             NaN
# 4  2021-10-09  Las Vegas, Nevada, USA     USA     NaN  ...             NaN
#
# ...

# %%
for i in data.columns:
    print(i,"-------",data[i].isnull().sum())
# Out:
# R_fighter ------- 0
# B_fighter ------- 0
# R_odds ------- 0
# B_odds ------- 0
# R_ev ------- 0
# B_ev ------- 0
# date ------- 0
# location ------- 0
# country ------- 0
# Winner ------- 9
# title_bout ------- 0
# weight_class ------- 0
# gender ------- 0
# no_of_rounds ------- 0
# B_current_lose_streak ------- 0
# B_current_win_streak ------- 0
# B_draw ------- 0
# B_avg_SIG_STR_landed ------- 0
# B_avg_SIG_STR_pct ------- 0
# B_avg_SUB_ATT ------- 0
# B_avg_TD_landed ------- 0
# B_avg_TD_pct ------- 0
# B_longest_win_streak ------- 0
# B_losses ------- 0
# B_total_rounds_fought ------- 0
# B_total_title_bouts ------- 0
# B_win_by_Decision_Majority ------- 0
# B_win_by_Decision_Split ------- 0
# B_win_by_Decision_Unanimous ------- 0
# B_win_by_KO/TKO ------- 0
# B_win_by_Submission ------- 0
# B_win_by_TKO_Doctor_Stoppage ------- 0
# B_wins ------- 0
# B_Stance ------- 0
# B_Height_cms ------- 0
# B_Reach_cms ------- 0
# B_Weight_lbs ------- 0
# R_current_lose_streak ------- 0
# ...

# %%
#fixing criteria: del cols which have more than 70% missing values, using loop
for i in data.columns:
    if ((data[i].isnull().sum()*100)/data.shape[0])>=70:
        data.drop(columns=[i],inplace=True) #column

# %%
for i in data.columns:
    print(i,"-------",data[i].isnull().sum())
# Out:
# R_fighter ------- 0
# B_fighter ------- 0
# R_odds ------- 0
# B_odds ------- 0
# R_ev ------- 0
# B_ev ------- 0
# date ------- 0
# location ------- 0
# country ------- 0
# title_bout ------- 0
# weight_class ------- 0
# gender ------- 0
# no_of_rounds ------- 0
# B_current_lose_streak ------- 0
# B_current_win_streak ------- 0
# B_draw ------- 0
# B_avg_SIG_STR_landed ------- 0
# B_avg_SIG_STR_pct ------- 0
# B_avg_SUB_ATT ------- 0
# B_avg_TD_landed ------- 0
# B_avg_TD_pct ------- 0
# B_longest_win_streak ------- 0
# B_losses ------- 0
# B_total_rounds_fought ------- 0
# B_total_title_bouts ------- 0
# B_win_by_Decision_Majority ------- 0
# B_win_by_Decision_Split ------- 0
# B_win_by_Decision_Unanimous ------- 0
# B_win_by_KO/TKO ------- 0
# B_win_by_Submission ------- 0
# B_win_by_TKO_Doctor_Stoppage ------- 0
# B_wins ------- 0
# B_Stance ------- 0
# B_Height_cms ------- 0
# B_Reach_cms ------- 0
# B_Weight_lbs ------- 0
# R_current_lose_streak ------- 0
# ...

# %%
l=["b_dec_odds","b_sub_odds","b_ko_odds"]
for i in l:
    print(i,"----",data[i].dtypes)
# Out:
# b_dec_odds ---- float64
# b_sub_odds ---- float64
# b_ko_odds ---- float64

# %%
for i in data.columns:
    if ((data[i].isnull().sum()*100)/data.shape[0])>=1:
          data[i].fillna(data[i].median(),inplace=True)

# %%
for i in l:
    print(i,"-------",data[i].isnull().sum())
# Out:
# b_dec_odds ------- 0
# b_sub_odds ------- 0
# b_ko_odds ------- 0
