# %% [markdown]
# # 17/11/2022

# %%
import pandas as pd

# %%
df=pd.read_excel("C:\\Users\\asus\\OneDrive\\Desktop\\Python@ms\\data_sets\\catalog.xlsx")
df
# Out:
#         id                 date      time continent_code   country_name  \
# 0       34  2007-02-03 00:00:00     Night            NaN  United States
# 1       42              3/22/07       NaN            NaN  United States
# 2       56  2007-06-04 00:00:00       NaN            NaN  United States
# 3       59              4/14/07       NaN            NaN         Canada
# 4       61              4/15/07       NaN            NaN  United States
# ...    ...                  ...       ...            ...            ...
# 1688  7535  2015-07-12 00:00:00       NaN            NaN  United States
# 1689  7537              2/22/16  00:00:00            NaN  United States
# 1690  7539              2/23/16       NaN            NaN  United States
# 1691  7540              2/26/16  21:06:00            NaN  United States
# 1692  7541  2016-02-03 00:00:00  08:00:00            NaN  United States
#
#      country_code  state/province  population         city/town  distance  \
# ...

# %%
#1st check type --- object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1693 entries, 0 to 1692
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1693 non-null   int64
#  1   date                  1690 non-null   object
#  2   time                  629 non-null    object
#  3   continent_code        164 non-null    object
#  4   country_name          1693 non-null   object
#  5   country_code          1693 non-null   object
#  6   state/province        1692 non-null   object
#  7   population            1693 non-null   int64
#  8   city/town             1689 non-null   object
#  9   distance              1692 non-null   float64
#  10  location_description  551 non-null    object
#  11  latitude              1692 non-null   float64
#  12  longitude             1692 non-null   float64
#  13  geolocation           1692 non-null   object
#  14  hazard_type           1693 non-null   object
# ...

# %%
#2nd check missing values

# %%
df.isnull().sum()
# Out:
# id                         0
# date                       3
# time                    1064
# continent_code          1529
# country_name               0
# country_code               0
# state/province             1
# population                 0
# city/town                  4
# distance                   1
# location_description    1142
# latitude                   1
# longitude                  1
# geolocation                1
# hazard_type                0
# landslide_type             1
# landslide_size             1
# trigger                    2
# storm_name              1561
# injuries                1178
# fatalities               247
# source_name              821
# source_link              100
# dtype: int64

# %%
df["date"].mode() #to take 1st value we use [0] as we need atleast one value ([0],[1] are indices as its series)
# Out:
# 0   2010-03-05
# 1   2013-12-09
# Name: date, dtype: datetime64[ns]

# %%
#3rd filling/imputing missing values
df["date"].fillna(df["date"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                         0
# date                       0
# time                    1064
# continent_code          1529
# country_name               0
# country_code               0
# state/province             1
# population                 0
# city/town                  4
# distance                   1
# location_description    1142
# latitude                   1
# longitude                  1
# geolocation                1
# hazard_type                0
# landslide_type             1
# landslide_size             1
# trigger                    2
# storm_name              1561
# injuries                1178
# fatalities               247
# source_name              821
# source_link              100
# dtype: int64

# %%
#4th convert date to date-time datatype
df["date"]=pd.to_datetime(df["date"])

# %%
df.dtypes
# Out:
# id                               int64
# date                    datetime64[ns]
# time                            object
# continent_code                  object
# country_name                    object
# country_code                    object
# state/province                  object
# population                       int64
# city/town                       object
# distance                       float64
# location_description            object
# latitude                       float64
# longitude                      float64
# geolocation                     object
# hazard_type                     object
# landslide_type                  object
# landslide_size                  object
# trigger                         object
# storm_name                      object
# injuries                       float64
# fatalities                     float64
# source_name                     object
# source_link                     object
# dtype: object

# %%
#dropping all other cols for now
df.drop(columns=["continent_code","location_description","source_link","source_name","fatalities",
                 "storm_name","injuries","city/town","distance","latitude","longitude","landslide_size","trigger"],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# date                 0
# time              1064
# country_name         0
# country_code         0
# state/province       1
# population           0
# geolocation          1
# hazard_type          0
# landslide_type       1
# dtype: int64

# %%
df["landslide_type"].fillna(df["landslide_type"].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# id                   0
# date                 0
# time              1064
# country_name         0
# country_code         0
# state/province       1
# population           0
# geolocation          1
# hazard_type          0
# landslide_type       0
# dtype: int64

# %%
from datetime import datetime as dt

# %%
#creating new col named year and extracting year from date col
df["Year"]=df.date.dt.year
df.head()
# Out:
#    id       date   time   country_name country_code state/province  \
# 0  34 2007-02-03  Night  United States           US       Virginia
# 1  42 2007-03-22    NaN  United States           US           Ohio
# 2  56 2007-06-04    NaN  United States           US   Pennsylvania
# 3  59 2007-04-14    NaN         Canada           CA         Quebec
# 4  61 2007-04-15    NaN  United States           US       Kentucky
#
#    population                                geolocation hazard_type  \
# 0       16000  (38.600900000000003, -77.268199999999993)   Landslide
# 1       17288  (40.517499999999998, -81.430499999999995)   Landslide
# 2       15930             (40.4377, -79.915999999999997)   Landslide
# 3       42786  (45.322600000000001, -73.777100000000004)   Landslide
# 4        6903  (37.432499999999997, -82.493099999999998)   Landslide
#
#        landslide_type  Year
# 0           Landslide  2007
# 1           Landslide  2007
# 2           Landslide  2007
# 3  Riverbank collapse  2007
# ...

# %%
#to find how many years
df["Year"].unique()
# Out:
# array([2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
#to extract months
df["Months"]=df.date.dt.month
df.head()
# Out:
#    id       date   time   country_name country_code state/province  \
# 0  34 2007-02-03  Night  United States           US       Virginia
# 1  42 2007-03-22    NaN  United States           US           Ohio
# 2  56 2007-06-04    NaN  United States           US   Pennsylvania
# 3  59 2007-04-14    NaN         Canada           CA         Quebec
# 4  61 2007-04-15    NaN  United States           US       Kentucky
#
#    population                                geolocation hazard_type  \
# 0       16000  (38.600900000000003, -77.268199999999993)   Landslide
# 1       17288  (40.517499999999998, -81.430499999999995)   Landslide
# 2       15930             (40.4377, -79.915999999999997)   Landslide
# 3       42786  (45.322600000000001, -73.777100000000004)   Landslide
# 4        6903  (37.432499999999997, -82.493099999999998)   Landslide
#
#        landslide_type  Year  Months
# 0           Landslide  2007       2
# 1           Landslide  2007       3
# ...

# %%
df["Months"].unique()
# Out:
# array([ 2,  3,  6,  4,  5,  1,  8,  7,  9, 11, 12, 10], dtype=int64)

# %%
df["m_name"]=df.date.dt.month_name()
df["m_name"].unique()
# Out:
# array(['February', 'March', 'June', 'April', 'May', 'January', 'August',
#        'July', 'September', 'November', 'December', 'October'],
#       dtype=object)

# %%
df["day"]=df.date.dt.day
df.head()
# Out:
#    id       date   time   country_name country_code state/province  \
# 0  34 2007-02-03  Night  United States           US       Virginia
# 1  42 2007-03-22    NaN  United States           US           Ohio
# 2  56 2007-06-04    NaN  United States           US   Pennsylvania
# 3  59 2007-04-14    NaN         Canada           CA         Quebec
# 4  61 2007-04-15    NaN  United States           US       Kentucky
#
#    population                                geolocation hazard_type  \
# 0       16000  (38.600900000000003, -77.268199999999993)   Landslide
# 1       17288  (40.517499999999998, -81.430499999999995)   Landslide
# 2       15930             (40.4377, -79.915999999999997)   Landslide
# 3       42786  (45.322600000000001, -73.777100000000004)   Landslide
# 4        6903  (37.432499999999997, -82.493099999999998)   Landslide
#
#        landslide_type  Year  Months    m_name  days    d_name  day
# 0           Landslide  2007       2  February     3  Saturday    3
# ...

# %%
df["d_name"]=df.date.dt.day_name()
df.head()
# Out:
#    id       date   time   country_name country_code state/province  \
# 0  34 2007-02-03  Night  United States           US       Virginia
# 1  42 2007-03-22    NaN  United States           US           Ohio
# 2  56 2007-06-04    NaN  United States           US   Pennsylvania
# 3  59 2007-04-14    NaN         Canada           CA         Quebec
# 4  61 2007-04-15    NaN  United States           US       Kentucky
#
#    population                                geolocation hazard_type  \
# 0       16000  (38.600900000000003, -77.268199999999993)   Landslide
# 1       17288  (40.517499999999998, -81.430499999999995)   Landslide
# 2       15930             (40.4377, -79.915999999999997)   Landslide
# 3       42786  (45.322600000000001, -73.777100000000004)   Landslide
# 4        6903  (37.432499999999997, -82.493099999999998)   Landslide
#
#        landslide_type  Year  Months    m_name  days    d_name  day
# 0           Landslide  2007       2  February     3  Saturday    3
# ...

# %%
df["dayofweek"]=df.date.dt.dayofweek
df["dayofweek"].unique()
# Out:
# array([5, 3, 0, 6, 4, 1, 2], dtype=int64)

# %%
#extracting week of year
df["week_no"]=df.date.dt.week
df["week_no"].unique()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_2680\3048674791.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df["week_no"]=df.date.dt.week
# array([ 5, 12, 23, 15, 16, 17, 21, 26,  1, 14, 32, 28, 30, 36, 45, 33, 34,
#         2,  6, 10, 19, 38, 39, 37, 50, 41, 42, 43, 44, 46, 48, 51, 22, 27,
#        18,  9, 40, 11, 13, 49, 25, 29, 31, 35, 24, 47, 52,  4, 20, 53,  3,
#         7,  8], dtype=int64)

# %%
#extracting weekend
import numpy as np
df["date is weekend"]=np.where(df["d_name"].isin(["Sunday","Saturday"]),1,0)
df["date is weekend"]
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       1
#        ..
# 1688    1
# 1689    0
# 1690    0
# 1691    0
# 1692    0
# Name: date is weekend, Length: 1693, dtype: int32

# %%
#extracting quarter of year
df["quarter"]=df.date.dt.quarter
df["quarter"].unique()
# Out:
# array([1, 2, 3, 4], dtype=int64)

# %%
df["time"].fillna(df["time"].mode()[0],inplace=True)
df["time"]
# Out:
# 0          Night
# 1          Night
# 2          Night
# 3          Night
# 4          Night
#           ...
# 1688       Night
# 1689    00:00:00
# 1690       Night
# 1691    21:06:00
# 1692    08:00:00
# Name: time, Length: 1693, dtype: object

# %%
df["time"].dtype #change to pd.datetime
# Out:
# dtype('O')

# %%
#df["time"]=pd.to_datetime(df["time"])

# %%
#today's date with current time
import datetime
today=datetime.datetime.today()
today
# Out:
# datetime.datetime(2022, 11, 17, 11, 24, 37, 723295)

# %%
#diff bw current date and other dates
today-df["date"]
# Out:
# 0      5766 days 11:24:37.723295
# 1      5719 days 11:24:37.723295
# 2      5645 days 11:24:37.723295
# 3      5696 days 11:24:37.723295
# 4      5695 days 11:24:37.723295
#                   ...
# 1688   2685 days 11:24:37.723295
# 1689   2460 days 11:24:37.723295
# 1690   2459 days 11:24:37.723295
# 1691   2456 days 11:24:37.723295
# 1692   2479 days 11:24:37.723295
# Name: date, Length: 1693, dtype: timedelta64[ns]

# %%
#for months difference
np.round((today-df["date"])/np.timedelta64(1,"M"),0)
# Out:
# 0       189.0
# 1       188.0
# 2       185.0
# 3       187.0
# 4       187.0
#         ...
# 1688     88.0
# 1689     81.0
# 1690     81.0
# 1691     81.0
# 1692     81.0
# Name: date, Length: 1693, dtype: float64

# %%
#extract time
df["time"]=df["date"].dt.time
df
# Out:
#         id       date      time   country_name country_code  state/province  \
# 0       34 2007-02-03  00:00:00  United States           US        Virginia
# 1       42 2007-03-22  00:00:00  United States           US            Ohio
# 2       56 2007-06-04  00:00:00  United States           US    Pennsylvania
# 3       59 2007-04-14  00:00:00         Canada           CA          Quebec
# 4       61 2007-04-15  00:00:00  United States           US        Kentucky
# ...    ...        ...       ...            ...          ...             ...
# 1688  7535 2015-07-12  00:00:00  United States           US  North Carolina
# 1689  7537 2016-02-22  00:00:00  United States           US   West Virginia
# 1690  7539 2016-02-23  00:00:00  United States           US   West Virginia
# 1691  7540 2016-02-26  00:00:00  United States           US   West Virginia
# 1692  7541 2016-02-03  00:00:00  United States           US         Vermont
#
# ...

# %%
#find the no. of landslides year wise
df.groupby("Year")["landslide_type"].value_counts().sort_values(ascending=True)
# Out:
# Year  landslide_type
# 2016  Mudslide                1
# 2014  Snow avalanche          1
#       Complex                 1
# 2010  Lahar                   1
# 2015  Creep                   1
# 2014  Riverbank collapse      1
# 2015  Unknown                 1
# 2008  Other                   1
#       Lahar                   1
# 2015  Rockslide               1
# 2013  Snow avalanche          1
# 2015  landslide               1
# 2007  Debris flow             1
# 2015  mudslide                1
# 2007  Riverbank collapse      1
# 2008  Debris flow             2
# 2010  Debris flow             2
# 2014  Creep                   2
# 2011  Rockfall                2
# 2009  Complex                 2
# 2011  Creep                   2
# 2008  Rockfall                2
# 2015  Riverbank collapse      3
# 2014  mudslide                3
#       Other                   4
# 2012  Debris flow             4
# 2011  Debris flow             4
# 2015  Debris flow             4
# ...

# %%
date=pd.date_range("1/1/2000",periods=12,freq="M")  ## date range is a pandas function to generate dates 
date #frequency according to months diff
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-30',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-30', '2000-10-31', '2000-11-30', '2000-12-31'],
#               dtype='datetime64[ns]', freq='M')
