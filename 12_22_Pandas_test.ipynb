# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\asus\\OneDrive\\Desktop\\Python@ms\\data_sets\\apy_2.csv")
df
# Out:
#        Unnamed: 0      State_Name District_Name  Crop_Year       Season  \
# 0               0       Karnataka         UDUPI       2005  Rabi
# 1               1  Madhya Pradesh       GWALIOR       2003  Whole Year
# 2               2  Andhra Pradesh      CHITTOOR       2010  Rabi
# 3               3  Andhra Pradesh       KRISHNA       2014  Rabi
# 4               4   Uttar Pradesh     SULTANPUR       2011  Rabi
# ...           ...             ...           ...        ...          ...
# 73822       73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823       73823    Chhattisgarh          DURG       2014  Rabi
# 73824       73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825       73825           Assam        KAMRUP       1998  Rabi
# 73826       73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# ...

# %%
df.drop(columns="Unnamed: 0",inplace=True)

# %%
df.dropna(axis=0,inplace=True)

# %%
for i in df.columns:
    print(i,"-----",df[i].isnull().sum())
# Out:
# State_Name ----- 0
# District_Name ----- 0
# Crop_Year ----- 0
# Season ----- 0
# Crop ----- 0
# Area ----- 0
# Production ----- 0

# %%
for i in  df.columns:
    print(i,"-----\n",df[i].unique())
# Out:
# State_Name -----
#  ['Karnataka' 'Madhya Pradesh' 'Andhra Pradesh' 'Uttar Pradesh' 'Rajasthan'
#  'Assam' 'Bihar' 'Odisha' 'Chhattisgarh' 'Kerala' 'Telangana '
#  'Maharashtra' 'Nagaland' 'Puducherry' 'Gujarat' 'Himachal Pradesh'
#  'Tamil Nadu' 'West Bengal' 'Jammu and Kashmir ' 'Arunachal Pradesh'
#  'Uttarakhand' 'Haryana' 'Mizoram' 'Manipur' 'Punjab' 'Jharkhand'
#  'Meghalaya' 'Andaman and Nicobar Islands' 'Sikkim' 'Tripura'
#  'Dadra and Nagar Haveli' 'Goa' 'Chandigarh']
# District_Name -----
#  ['UDUPI' 'GWALIOR' 'CHITTOOR' 'KRISHNA' 'SULTANPUR' 'JODHPUR' 'KAMRUP'
#  'SIVASAGAR' 'JEHANABAD' 'NAYAGARH' 'DIBRUGARH' 'MORENA' 'SIDHI' 'DURG'
#  'PATHANAMTHITTA' 'NIZAMABAD' 'DINDORI' 'LAKHIMPUR' 'KUSHI NAGAR' 'WARDHA'
#  'CHIKBALLAPUR' 'NAGAUR' 'BEGUSARAI' 'WOKHA' 'MAHE' 'KIPHIRE' 'JAMNAGAR'
#  'JALNA' 'JHANSI' 'LUCKNOW' 'HAMIRPUR' 'DINDIGUL' 'DARJEELING' 'BHANDARA'
#  'BANKA' 'CHIRANG' 'JAIPUR' 'KARAULI' 'AJMER' 'NARMADA'
# ...

# %%
#1. Which of these crops are produced during the Summer season? (select option with all that apply)
df[(df["Season"]=='Summer     ')]["Crop"].unique()
# Out:
# array(['Groundnut', 'Maize', 'Rice', 'Sesamum', 'Wheat', 'Onion', 'Urad',
#        'Peas & beans (Pulses)', 'Sunflower', 'Ragi', 'Bajra',
#        'Moong(Green Gram)', 'Cotton(lint)', 'Jowar', 'Cowpea(Lobia)',
#        'Tobacco', 'Horse-gram', 'Dry chillies', 'Paddy', 'Turmeric',
#        'Arhar/Tur', 'Banana', 'Potato', 'Dry ginger', 'Brinjal',
#        'Sugarcane', 'Other  Rabi pulses', 'Small millets',
#        'Total foodgrain'], dtype=object)

# %%
#2. During which year did Haryana have the highest crop production?
x=df[df["State_Name"]=='Haryana']
x
# Out:
#       State_Name District_Name  Crop_Year       Season                 Crop  \
# 77       Haryana         MEWAT       2006  Rabi                        Gram
# 114      Haryana          JIND       2008  Kharif              Cotton(lint)
# 132      Haryana  MAHENDRAGARH       2006  Kharif                     Bajra
# 162      Haryana       JHAJJAR       2002  Whole Year                Banana
# 185      Haryana       BHIWANI       1997  Kharif       Other Kharif pulses
# ...          ...           ...        ...          ...                  ...
# 73392    Haryana       GURGAON       1999  Whole Year                 Onion
# 73558    Haryana       PANIPAT       2008  Kharif                      Rice
# 73621    Haryana       JHAJJAR       2004  Rabi                       Wheat
# 73635    Haryana  MAHENDRAGARH       2006  Rabi                       Wheat
# 73772    Haryana       JHAJJAR       2006  Rabi           Rapeseed &Mustard
#
#            Area  Production
# ...

# %%
x.groupby(["Crop_Year"])["Production"].sum().sort_values(ascending=False) #groupby on year and sum on production
# Out:
# Crop_Year
# 2008    9647100.0
# 2005    9328300.0
# 2011    9021300.0
# 2003    8437562.0
# 2012    7996416.0
# 2002    7837700.0
# 2004    7523400.0
# 2007    7323500.0
# 1999    7188901.0
# 2001    7009900.0
# 1998    6653600.0
# 2006    6566600.0
# 2000    5872800.0
# 2010    5548900.0
# 2009    5214480.0
# 1997    3376800.0
# Name: Production, dtype: float64

# %%
#3. The maximum and minimum area for production were in the years?
df.groupby(["Crop_Year"])["Area"].agg(["sum"]).reset_index().sort_values(by="sum",ascending=False)
#sum of all areas
# Out:
#     Crop_Year          sum
# 0        1997  68245111.00
# 7        2004  53445367.24
# 2        1999  51841049.00
# 9        2006  51393712.02
# 13       2010  50813109.78
# 12       2009  50772638.00
# 3        2000  50530198.00
# 11       2008  49604477.00
# 1        1998  49317287.00
# 6        2003  48954140.97
# 5        2002  48328531.15
# 14       2011  45835655.41
# 8        2005  45296672.88
# 10       2007  44971304.38
# 15       2012  44369268.00
# 4        2001  43603438.77
# 16       2013  41895685.00
# 17       2014  34188857.84
# 18       2015   1313314.00

# %%
#4. Which state in India had the second lowest crop production? (overall, for all years)
x=df.groupby(["State_Name"])["Production"].sum().sort_values()
x
# Out:
# State_Name
# Chandigarh                     1.580450e+04
# Mizoram                        4.579428e+05
# Sikkim                         5.507250e+05
# Dadra and Nagar Haveli         6.247060e+05
# Manipur                        1.658617e+06
# Arunachal Pradesh              2.035912e+06
# Jharkhand                      3.319141e+06
# Meghalaya                      3.639914e+06
# Nagaland                       3.925012e+06
# Jammu and Kashmir              4.018134e+06
# Tripura                        4.278173e+06
# Himachal Pradesh               5.198802e+06
# Chhattisgarh                   3.132986e+07
# Uttarakhand                    4.017398e+07
# Odisha                         4.563306e+07
# Puducherry                     7.326832e+07
# Rajasthan                      8.671658e+07
# Haryana                        1.145473e+08
# Bihar                          1.151581e+08
# Telangana                      1.202722e+08
# Madhya Pradesh                 1.337226e+08
# ...

# %%
#5. What were the top three produced crops in the year 2012?
x=df[df["Crop_Year"]==2012]
x
# Out:
#            State_Name     District_Name  Crop_Year       Season  \
# 26           Nagaland           KIPHIRE       2012  Rabi
# 44     Madhya Pradesh       HOSHANGABAD       2012  Whole Year
# 74       Chhattisgarh          DHAMTARI       2012  Kharif
# 76        Uttarakhand  UDAM SINGH NAGAR       2012  Rabi
# 94         Tamil Nadu       KRISHNAGIRI       2012  Kharif
# ...               ...               ...        ...          ...
# 73706          Kerala            KOLLAM       2012  Whole Year
# 73724   Uttar Pradesh             UNNAO       2012  Rabi
# 73769       Karnataka   BENGALURU URBAN       2012  Whole Year
# 73771       Meghalaya  SOUTH GARO HILLS       2012  Whole Year
# 73805  Andhra Pradesh           KRISHNA       2012  Rabi
#
#                     Crop    Area  Production
# 26     Rapeseed &Mustard  1190.0      1200.0
# 44             Coriander   305.0       143.0
# 74            Horse-gram   124.0        42.0
# 76                  Gram    28.0        17.0
# ...

# %%
x.groupby(["Crop"])["Production"].sum().sort_values(ascending=False).head(3)
# Out:
# Crop
# Coconut      1.208299e+09
# Sugarcane    1.143474e+08
# Rice         3.371318e+07
# Name: Production, dtype: float64

# %%
#6. What is the standard deviation for Area of production?
df["Area"].describe()
# Out:
# count    7.267900e+04
# mean     1.203539e+04
# std      4.917760e+04
# min      5.000000e-01
# 25%      8.500000e+01
# 50%      6.000000e+02
# 75%      4.475000e+03
# max      4.205800e+06
# Name: Area, dtype: float64

# %%
df["Area"].std()
# Out:
# 49177.603127123424

# %%
#7. Which is the crop that gave the highest production to the state of Andhra Pradesh?
x=df[df["State_Name"]=="Andhra Pradesh"]
x
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 2      Andhra Pradesh      CHITTOOR       2010  Rabi
# 3      Andhra Pradesh       KRISHNA       2014  Rabi
# 86     Andhra Pradesh       KURNOOL       2011  Kharif
# 126    Andhra Pradesh      CHITTOOR       2000  Whole Year
# 175    Andhra Pradesh      CHITTOOR       2007  Kharif
# ...               ...           ...        ...          ...
# 73681  Andhra Pradesh  SPSR NELLORE       2006  Whole Year
# 73713  Andhra Pradesh       KRISHNA       2005  Kharif
# 73787  Andhra Pradesh      PRAKASAM       2006  Rabi
# 73805  Andhra Pradesh       KRISHNA       2012  Rabi
# 73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 2                Sesamum     334.0       118.0
# 3                 Tomato     538.0      7289.0
# 86     Moong(Green Gram)    1284.0       824.0
# 126            Cashewnut     126.0        27.0
# 175           Horse-gram    4000.0      2000.0
# ...

# %%
x.groupby("Crop")["Production"].max().sort_values(ascending=False)
# Out:
# Crop
# Coconut              780162000.0
# Sugarcane              3697441.0
# Rice                   1624324.0
# Maize                   950884.0
# Cotton(lint)            809620.0
#                         ...
# Cucumber                     0.0
# Bottle Gourd                 0.0
# Other Vegetables             0.0
# other fibres                 0.0
# Peas  (vegetable)            0.0
# Name: Production, Length: 67, dtype: float64

# %%
#8.Which of the following statements is true? (Select all that applies)
df.groupby(["Season"])["Production"].sum().sort_values(ascending=False)
# Out:
# Season
# Whole Year     3.009350e+10
# Kharif         1.282057e+09
# Rabi           5.928215e+08
# Winter         1.294610e+08
# Summer         5.199288e+07
# Autumn         1.889659e+07
# Name: Production, dtype: float64

# %%
#9. Which state has the lowest area of production?
df.groupby(["State_Name"])["Area"].sum().sort_values(ascending=True)
# Out:
# State_Name
# Chandigarh                     2.791000e+03
# Andaman and Nicobar Islands    8.531894e+04
# Dadra and Nagar Haveli         1.182820e+05
# Puducherry                     1.206340e+05
# Goa                            2.702040e+05
# Mizoram                        2.711313e+05
# Sikkim                         3.922050e+05
# Manipur                        6.121800e+05
# Meghalaya                      1.270237e+06
# Arunachal Pradesh              1.283609e+06
# Tripura                        1.605874e+06
# Nagaland                       1.800631e+06
# Jammu and Kashmir              2.744164e+06
# Jharkhand                      2.748473e+06
# Himachal Pradesh               2.897344e+06
# Uttarakhand                    5.714422e+06
# Kerala                         8.871677e+06
# Assam                          2.065623e+07
# Telangana                      2.225371e+07
# Chhattisgarh                   2.547540e+07
# Haryana                        2.756965e+07
# ...

# %%
#10. What is the mean for the area of production?
df["Area"].mean()
# Out:
# 12035.385977242398

# %%
df.corr() #correlation
# Out:
#             Crop_Year      Area  Production
# Crop_Year    1.000000 -0.025927    0.005928
# Area        -0.025927  1.000000    0.037686
# Production   0.005928  0.037686    1.000000

# %%
#12. Which is the only crop that has the highest production during autumn, summer, and winter?
#x=df[df["Season"]=='Autumn     ','Winter     ','Summer     ']

# %%
x=df.groupby(["Season","Crop"])["Production"].sum()
x1=x.reset_index()
x1
# Out:
#           Season          Crop  Production
# 0    Autumn          Arhar/Tur      3937.0
# 1    Autumn             Banana      3980.0
# 2    Autumn       Dry chillies     10513.0
# 3    Autumn         Dry ginger       360.0
# 4    Autumn          Groundnut     97968.5
# ..           ...           ...         ...
# 312  Winter            Sesamum     32707.8
# 313  Winter          Sugarcane   4839051.3
# 314  Winter       Sweet potato        30.0
# 315  Winter               Urad     74790.7
# 316  Winter              Wheat      1652.0
#
# [317 rows x 3 columns]

# %%
x2=x1[x1["Season"]=='Autumn     ']
x2[x2["Production"]==x2["Production"].max()]
# Out:
#          Season  Crop  Production
# 13  Autumn       Rice  14820963.7

# %%
x2=x1[x1["Season"]=='Winter     ']
x2[x2["Production"]==x2["Production"].max()]
# Out:
#           Season  Crop    Production
# 310  Winter       Rice  1.113293e+08

# %%
x2=x1[x1["Season"]=='Summer     ']
x2[x2["Production"]==x2["Production"].max()]
# Out:
#           Season  Crop  Production
# 183  Summer       Rice  38709052.2
